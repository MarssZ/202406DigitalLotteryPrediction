# %%
import pandas as pd
# 超参数
COLS_LOTTERY_NUMBER_1 = '号码1'
COLS_LOTTERY_NUMBER_2 = '号码2'
COLS_LOTTERY_NUMBER_3 = '号码3'
COLS_INDEX = '期号'
COLS_ALL = [COLS_INDEX, COLS_LOTTERY_NUMBER_1, COLS_LOTTERY_NUMBER_2, COLS_LOTTERY_NUMBER_3, '跨度','和值']

# 读取excel文件并获取指定列dataframe
df = pd.read_excel('../Data/福彩3D历史开奖.xlsx', usecols=COLS_ALL)
df = df[:500]
print(df)
# Out:
#           期号  号码1  号码2  号码3  跨度  和值
# 0    2024270    6    9    9   3  24
# 1    2024269    3    8    8   5  19
# 2    2024268    9    3    1   8  13
# 3    2024267    2    2    7   5  11
# 4    2024266    3    9    0   9  12
# ..       ...  ...  ...  ...  ..  ..
# 495  2023126    4    9    6   5  19
# 496  2023125    0    0    7   7   7
# 497  2023124    2    3    6   4  11
# 498  2023123    8    0    4   8  12
# 499  2023122    4    1    2   3   7
#
# [500 rows x 6 columns]

# %%
### 添加所需要的列 ###
import utils
cols_lottery = [COLS_LOTTERY_NUMBER_1, COLS_LOTTERY_NUMBER_2, COLS_LOTTERY_NUMBER_3]

# 特征列：本期是否有某数字
df['本期是否有0'] = utils.check_number_in_lottery(df, cols_lottery, 0)
df['本期是否有1'] = utils.check_number_in_lottery(df, cols_lottery, 1)
df['本期是否有2'] = utils.check_number_in_lottery(df, cols_lottery, 2)
df['本期是否有3'] = utils.check_number_in_lottery(df, cols_lottery, 3)
df['本期是否有4'] = utils.check_number_in_lottery(df, cols_lottery, 4)
df['本期是否有5'] = utils.check_number_in_lottery(df, cols_lottery, 5)
df['本期是否有6'] = utils.check_number_in_lottery(df, cols_lottery, 6)
df['本期是否有7'] = utils.check_number_in_lottery(df, cols_lottery, 7)
df['本期是否有8'] = utils.check_number_in_lottery(df, cols_lottery, 8)
df['本期是否有9'] = utils.check_number_in_lottery(df, cols_lottery, 9)

# 特征列：奇偶
df['和值为偶数'] = utils.check_even_number(df, '和值')
df['跨度为偶数'] = utils.check_even_number(df, '跨度')
df['号码1为偶数'] = utils.check_even_number(df, COLS_LOTTERY_NUMBER_1)
df['号码2为偶数'] = utils.check_even_number(df, COLS_LOTTERY_NUMBER_2)
df['号码3为偶数'] = utils.check_even_number(df, COLS_LOTTERY_NUMBER_3)
df['本期全为偶数'] = utils.check_all_even_numbers(df, cols_lottery)
df['本期全为奇数'] = utils.check_all_odd_numbers(df, cols_lottery)

# 特征列：形态
df['是组六'] = utils.check_no_same(df, cols_lottery)
df['是组三'] = utils.check_two_same(df, cols_lottery)
df['是豹子'] = utils.check_three_same(df, cols_lottery)


# 预测列
# df['下期是否全为偶数'] = utils.predict_all_even_numbers(df, cols_lottery)
# df['下期百位是否有2'] = utils.check_number_in_next_column(df, COLS_LOTTERY_NUMBER_1, 3)

# 预测列：形态
df['下期是组六'] = utils.predict_no_same(df, cols_lottery)
# df['下期是组三'] = utils.predict_two_same(df, cols_lottery)
# df['下期是豹子'] = utils.predict_three_same(df, cols_lottery)

df = df.drop(df.index[0])    # 从df中删除第一行，因为这一行没办法确认下一期是否有指定数字
print(df.head(5))

# 定义好预测列
COLS_Y = '下期是组六'
COLS_Y_CLASSNAME = ["不是组六", "是组六"]
CLASS_WEIGHTS = {0: 1, 1: 1}
# Out:
#         期号  号码1  号码2  号码3  跨度  和值  本期是否有0  本期是否有1  本期是否有2  本期是否有3  ...  跨度为偶数  \
# 1  2024269    3    8    8   5  19   False   False   False    True  ...  False
# 2  2024268    9    3    1   8  13   False    True   False    True  ...   True
# 3  2024267    2    2    7   5  11   False   False    True   False  ...  False
# 4  2024266    3    9    0   9  12    True   False   False    True  ...  False
# 5  2024265    2    4    5   3  11   False   False    True   False  ...  False
#
#    号码1为偶数  号码2为偶数  号码3为偶数  本期全为偶数  本期全为奇数    是组六    是组三    是豹子  下期是组六
# 1   False    True    True   False   False  False   True  False  False
# 2   False   False   False   False    True   True  False  False  False
# 3    True    True   False   False   False  False   True  False   True
# 4   False   False    True   False   False   True  False  False  False
# 5    True    True   False   False   False   True  False  False   True
#
# [5 rows x 27 columns]

# %%
from sklearn.model_selection import train_test_split
import numpy as np

## 取需要训练的值
cols_x = df.drop(columns=[COLS_Y,COLS_INDEX])
cols_y = df[COLS_Y]
# print(cols_x)
# print(cols_y)
cols_x_names = cols_x.columns.tolist()

# 随机选择3个特征列
selected_features = np.random.choice(cols_x_names, size=3, replace=False)

Xtrain, Xtest, Ytrain, ytest = train_test_split(cols_x[selected_features], cols_y, test_size = 0.002, random_state=102) 

print(Xtrain.shape)
print(Xtest.shape)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[8], line 2
#       1 from sklearn.model_selection import train_test_split
# ----> 2 from numpy import np
#       4 ## 取需要训练的值
#       5 cols_x = df.drop(columns=[COLS_Y,COLS_INDEX])
#
# ImportError: cannot import name 'np' from 'numpy' (e:\Python\Lib\site-packages\numpy\__init__.py)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, accuracy_score

# 训练模型
clf = RandomForestClassifier(n_estimators=5000,  
                             max_depth = 3, 
                             criterion='entropy',
                             min_samples_leaf=5, 
                             max_features = 3,
                             class_weight=CLASS_WEIGHTS,
                             bootstrap=False,   # 特别核心，所有决策树都用全部数据做训练
                             random_state = 13)  #最大{max_depth}层，最少也需要{lefa}个样本才生成分支
clf = clf.fit(Xtrain, Ytrain) 

# 预测测试集
y_pred = clf.predict(Xtest)

# 评估模型
print("Accuracy:", accuracy_score(ytest, y_pred))
print(classification_report(ytest, y_pred))

#print('精准度： '+str(clf.score(Xtest, ytest))) #返回预测的准确度
#print([*zip(feature_name,clf.feature_importances_)]) #返回决策树各自变量的重要程度
# Out:
# Accuracy: 1.0
#               precision    recall  f1-score   support
#
#         True       1.00      1.00      1.00         1
#
#     accuracy                           1.00         1
#    macro avg       1.00      1.00      1.00         1
# weighted avg       1.00      1.00      1.00         1

# %%
### 找到那些值得关注的树

# 遍历每棵树，检查它们的节点熵值
for i, tree in enumerate(clf.estimators_):
    tree_ = tree.tree_
    
    for j in range(tree_.node_count):
        # 获取节点的熵值
        node_entropy = tree_.impurity[j]
        
        # 获取节点的value（类别的统计信息）
        node_value = tree_.value[j]
        # 只关注第二个类别标签（对应于 'true'）
        true_class_value = node_value[0][1] if node_value.size > 1 else 0
        if true_class_value == 1:
            print(f"Tree {i} has 100% true leaf.")
# Out:
# Tree 0 has 100% true leaf.
# Tree 5 has 100% true leaf.
# Tree 6 has 100% true leaf.
# Tree 10 has 100% true leaf.
# Tree 19 has 100% true leaf.
# Tree 24 has 100% true leaf.
# Tree 27 has 100% true leaf.
# Tree 33 has 100% true leaf.
# Tree 40 has 100% true leaf.
# Tree 45 has 100% true leaf.
# Tree 53 has 100% true leaf.
# Tree 61 has 100% true leaf.
# Tree 70 has 100% true leaf.
# Tree 73 has 100% true leaf.
# Tree 78 has 100% true leaf.
# Tree 81 has 100% true leaf.
# Tree 83 has 100% true leaf.
# Tree 88 has 100% true leaf.
# Tree 91 has 100% true leaf.
# Tree 95 has 100% true leaf.
# Tree 100 has 100% true leaf.
# Tree 105 has 100% true leaf.
# Tree 112 has 100% true leaf.
# Tree 118 has 100% true leaf.
# Tree 118 has 100% true leaf.
# Tree 120 has 100% true leaf.
# Tree 122 has 100% true leaf.
# Tree 122 has 100% true leaf.
# Tree 127 has 100% true leaf.
# Tree 129 has 100% true leaf.
# Tree 129 has 100% true leaf.
# Tree 130 has 100% true leaf.
# Tree 140 has 100% true leaf.
# Tree 152 has 100% true leaf.
# Tree 153 has 100% true leaf.
# Tree 155 has 100% true leaf.
# Tree 156 has 100% true leaf.
# Tree 157 has 100% true leaf.
# Tree 159 has 100% true leaf.
# Tree 160 has 100% true leaf.
# Tree 160 has 100% true leaf.
# Tree 164 has 100% true leaf.
# Tree 166 has 100% true leaf.
# Tree 170 has 100% true leaf.
# Tree 176 has 100% true leaf.
# Tree 179 has 100% true leaf.
# Tree 184 has 100% true leaf.
# Tree 187 has 100% true leaf.
# Tree 193 has 100% true leaf.
# Tree 200 has 100% true leaf.
# Tree 203 has 100% true leaf.
# Tree 207 has 100% true leaf.
# Tree 207 has 100% true leaf.
# Tree 210 has 100% true leaf.
# Tree 212 has 100% true leaf.
# Tree 212 has 100% true leaf.
# Tree 216 has 100% true leaf.
# Tree 220 has 100% true leaf.
# Tree 222 has 100% true leaf.
# Tree 226 has 100% true leaf.
# Tree 227 has 100% true leaf.
# Tree 228 has 100% true leaf.
# Tree 235 has 100% true leaf.
# Tree 235 has 100% true leaf.
# Tree 236 has 100% true leaf.
# Tree 237 has 100% true leaf.
# Tree 245 has 100% true leaf.
# Tree 245 has 100% true leaf.
# Tree 246 has 100% true leaf.
# Tree 254 has 100% true leaf.
# Tree 258 has 100% true leaf.
# Tree 262 has 100% true leaf.
# Tree 272 has 100% true leaf.
# Tree 273 has 100% true leaf.
# Tree 277 has 100% true leaf.
# Tree 278 has 100% true leaf.
# Tree 282 has 100% true leaf.
# Tree 284 has 100% true leaf.
# Tree 286 has 100% true leaf.
# Tree 294 has 100% true leaf.
# Tree 295 has 100% true leaf.
# Tree 296 has 100% true leaf.
# Tree 300 has 100% true leaf.
# Tree 301 has 100% true leaf.
# Tree 304 has 100% true leaf.
# Tree 308 has 100% true leaf.
# Tree 312 has 100% true leaf.
# Tree 314 has 100% true leaf.
# Tree 320 has 100% true leaf.
# Tree 322 has 100% true leaf.
# Tree 323 has 100% true leaf.
# Tree 324 has 100% true leaf.
# Tree 333 has 100% true leaf.
# Tree 334 has 100% true leaf.
# Tree 334 has 100% true leaf.
# Tree 344 has 100% true leaf.
# Tree 345 has 100% true leaf.
# Tree 346 has 100% true leaf.
# Tree 349 has 100% true leaf.
# Tree 356 has 100% true leaf.
# Tree 357 has 100% true leaf.
# Tree 367 has 100% true leaf.
# Tree 371 has 100% true leaf.
# Tree 375 has 100% true leaf.
# Tree 390 has 100% true leaf.
# Tree 394 has 100% true leaf.
# Tree 397 has 100% true leaf.
# Tree 403 has 100% true leaf.
# Tree 406 has 100% true leaf.
# Tree 410 has 100% true leaf.
# Tree 410 has 100% true leaf.
# Tree 411 has 100% true leaf.
# Tree 417 has 100% true leaf.
# Tree 418 has 100% true leaf.
# Tree 420 has 100% true leaf.
# Tree 421 has 100% true leaf.
# Tree 426 has 100% true leaf.
# Tree 441 has 100% true leaf.
# Tree 442 has 100% true leaf.
# Tree 443 has 100% true leaf.
# Tree 445 has 100% true leaf.
# Tree 448 has 100% true leaf.
# Tree 450 has 100% true leaf.
# Tree 451 has 100% true leaf.
# Tree 452 has 100% true leaf.
# Tree 457 has 100% true leaf.
# Tree 464 has 100% true leaf.
# Tree 467 has 100% true leaf.
# Tree 470 has 100% true leaf.
# Tree 474 has 100% true leaf.
# Tree 478 has 100% true leaf.
# Tree 493 has 100% true leaf.
# Tree 500 has 100% true leaf.
# Tree 504 has 100% true leaf.
# Tree 515 has 100% true leaf.
# Tree 518 has 100% true leaf.
# Tree 524 has 100% true leaf.
# Tree 525 has 100% true leaf.
# Tree 526 has 100% true leaf.
# Tree 535 has 100% true leaf.
# Tree 539 has 100% true leaf.
# Tree 546 has 100% true leaf.
# Tree 549 has 100% true leaf.
# Tree 550 has 100% true leaf.
# Tree 552 has 100% true leaf.
# Tree 556 has 100% true leaf.
# Tree 561 has 100% true leaf.
# Tree 562 has 100% true leaf.
# Tree 566 has 100% true leaf.
# Tree 567 has 100% true leaf.
# Tree 568 has 100% true leaf.
# Tree 572 has 100% true leaf.
# Tree 576 has 100% true leaf.
# Tree 579 has 100% true leaf.
# Tree 580 has 100% true leaf.
# Tree 583 has 100% true leaf.
# Tree 584 has 100% true leaf.
# Tree 587 has 100% true leaf.
# Tree 596 has 100% true leaf.
# Tree 600 has 100% true leaf.
# Tree 604 has 100% true leaf.
# Tree 606 has 100% true leaf.
# Tree 617 has 100% true leaf.
# Tree 619 has 100% true leaf.
# Tree 627 has 100% true leaf.
# Tree 633 has 100% true leaf.
# Tree 638 has 100% true leaf.
# Tree 638 has 100% true leaf.
# Tree 638 has 100% true leaf.
# Tree 641 has 100% true leaf.
# Tree 643 has 100% true leaf.
# Tree 645 has 100% true leaf.
# Tree 649 has 100% true leaf.
# Tree 650 has 100% true leaf.
# Tree 651 has 100% true leaf.
# Tree 655 has 100% true leaf.
# Tree 659 has 100% true leaf.
# Tree 660 has 100% true leaf.
# Tree 669 has 100% true leaf.
# Tree 670 has 100% true leaf.
# Tree 676 has 100% true leaf.
# Tree 679 has 100% true leaf.
# Tree 686 has 100% true leaf.
# Tree 700 has 100% true leaf.
# Tree 700 has 100% true leaf.
# Tree 703 has 100% true leaf.
# Tree 705 has 100% true leaf.
# Tree 706 has 100% true leaf.
# Tree 708 has 100% true leaf.
# Tree 723 has 100% true leaf.
# Tree 728 has 100% true leaf.
# Tree 729 has 100% true leaf.
# Tree 730 has 100% true leaf.
# Tree 735 has 100% true leaf.
# Tree 742 has 100% true leaf.
# Tree 743 has 100% true leaf.
# Tree 745 has 100% true leaf.
# Tree 751 has 100% true leaf.
# Tree 754 has 100% true leaf.
# Tree 755 has 100% true leaf.
# Tree 758 has 100% true leaf.
# Tree 759 has 100% true leaf.
# Tree 761 has 100% true leaf.
# Tree 761 has 100% true leaf.
# Tree 766 has 100% true leaf.
# Tree 767 has 100% true leaf.
# Tree 775 has 100% true leaf.
# Tree 777 has 100% true leaf.
# Tree 790 has 100% true leaf.
# Tree 793 has 100% true leaf.
# Tree 794 has 100% true leaf.
# Tree 795 has 100% true leaf.
# Tree 796 has 100% true leaf.
# Tree 799 has 100% true leaf.
# Tree 804 has 100% true leaf.
# Tree 820 has 100% true leaf.
# Tree 821 has 100% true leaf.
# Tree 822 has 100% true leaf.
# Tree 824 has 100% true leaf.
# Tree 825 has 100% true leaf.
# Tree 829 has 100% true leaf.
# Tree 838 has 100% true leaf.
# Tree 840 has 100% true leaf.
# Tree 841 has 100% true leaf.
# Tree 842 has 100% true leaf.
# Tree 853 has 100% true leaf.
# Tree 854 has 100% true leaf.
# Tree 857 has 100% true leaf.
# Tree 858 has 100% true leaf.
# Tree 867 has 100% true leaf.
# Tree 867 has 100% true leaf.
# Tree 870 has 100% true leaf.
# Tree 873 has 100% true leaf.
# Tree 876 has 100% true leaf.
# Tree 877 has 100% true leaf.
# Tree 880 has 100% true leaf.
# Tree 883 has 100% true leaf.
# Tree 883 has 100% true leaf.
# Tree 885 has 100% true leaf.
# Tree 887 has 100% true leaf.
# Tree 899 has 100% true leaf.
# Tree 905 has 100% true leaf.
# Tree 907 has 100% true leaf.
# Tree 908 has 100% true leaf.
# Tree 910 has 100% true leaf.
# Tree 912 has 100% true leaf.
# Tree 914 has 100% true leaf.
# Tree 915 has 100% true leaf.
# Tree 927 has 100% true leaf.
# Tree 929 has 100% true leaf.
# Tree 932 has 100% true leaf.
# Tree 936 has 100% true leaf.
# Tree 939 has 100% true leaf.
# Tree 941 has 100% true leaf.
# Tree 942 has 100% true leaf.
# Tree 944 has 100% true leaf.
# Tree 949 has 100% true leaf.
# Tree 955 has 100% true leaf.
# Tree 956 has 100% true leaf.
# Tree 959 has 100% true leaf.
# Tree 973 has 100% true leaf.
# Tree 975 has 100% true leaf.
# Tree 977 has 100% true leaf.
# Tree 987 has 100% true leaf.
# Tree 988 has 100% true leaf.
# Tree 992 has 100% true leaf.
# Tree 1004 has 100% true leaf.
# Tree 1006 has 100% true leaf.
# Tree 1009 has 100% true leaf.
# Tree 1010 has 100% true leaf.
# Tree 1011 has 100% true leaf.
# Tree 1013 has 100% true leaf.
# Tree 1016 has 100% true leaf.
# Tree 1029 has 100% true leaf.
# Tree 1031 has 100% true leaf.
# Tree 1032 has 100% true leaf.
# Tree 1037 has 100% true leaf.
# Tree 1042 has 100% true leaf.
# Tree 1044 has 100% true leaf.
# Tree 1046 has 100% true leaf.
# Tree 1055 has 100% true leaf.
# Tree 1061 has 100% true leaf.
# Tree 1070 has 100% true leaf.
# Tree 1073 has 100% true leaf.
# Tree 1077 has 100% true leaf.
# Tree 1077 has 100% true leaf.
# Tree 1078 has 100% true leaf.
# Tree 1080 has 100% true leaf.
# Tree 1094 has 100% true leaf.
# Tree 1095 has 100% true leaf.
# Tree 1095 has 100% true leaf.
# Tree 1097 has 100% true leaf.
# Tree 1098 has 100% true leaf.
# Tree 1099 has 100% true leaf.
# Tree 1101 has 100% true leaf.
# Tree 1103 has 100% true leaf.
# Tree 1120 has 100% true leaf.
# Tree 1127 has 100% true leaf.
# Tree 1134 has 100% true leaf.
# Tree 1135 has 100% true leaf.
# Tree 1137 has 100% true leaf.
# Tree 1139 has 100% true leaf.
# Tree 1141 has 100% true leaf.
# Tree 1146 has 100% true leaf.
# Tree 1149 has 100% true leaf.
# Tree 1151 has 100% true leaf.
# Tree 1161 has 100% true leaf.
# Tree 1166 has 100% true leaf.
# Tree 1168 has 100% true leaf.
# Tree 1169 has 100% true leaf.
# Tree 1170 has 100% true leaf.
# Tree 1173 has 100% true leaf.
# Tree 1174 has 100% true leaf.
# Tree 1175 has 100% true leaf.
# Tree 1180 has 100% true leaf.
# Tree 1181 has 100% true leaf.
# Tree 1193 has 100% true leaf.
# Tree 1197 has 100% true leaf.
# Tree 1209 has 100% true leaf.
# Tree 1210 has 100% true leaf.
# Tree 1215 has 100% true leaf.
# Tree 1220 has 100% true leaf.
# Tree 1227 has 100% true leaf.
# Tree 1233 has 100% true leaf.
# Tree 1241 has 100% true leaf.
# Tree 1242 has 100% true leaf.
# Tree 1243 has 100% true leaf.
# Tree 1246 has 100% true leaf.
# Tree 1247 has 100% true leaf.
# Tree 1267 has 100% true leaf.
# Tree 1270 has 100% true leaf.
# Tree 1277 has 100% true leaf.
# Tree 1285 has 100% true leaf.
# Tree 1286 has 100% true leaf.
# Tree 1290 has 100% true leaf.
# Tree 1296 has 100% true leaf.
# Tree 1298 has 100% true leaf.
# Tree 1303 has 100% true leaf.
# Tree 1307 has 100% true leaf.
# Tree 1312 has 100% true leaf.
# Tree 1313 has 100% true leaf.
# Tree 1314 has 100% true leaf.
# Tree 1324 has 100% true leaf.
# Tree 1330 has 100% true leaf.
# Tree 1332 has 100% true leaf.
# Tree 1340 has 100% true leaf.
# Tree 1341 has 100% true leaf.
# Tree 1342 has 100% true leaf.
# Tree 1343 has 100% true leaf.
# Tree 1350 has 100% true leaf.
# Tree 1354 has 100% true leaf.
# Tree 1355 has 100% true leaf.
# Tree 1355 has 100% true leaf.
# Tree 1358 has 100% true leaf.
# Tree 1359 has 100% true leaf.
# Tree 1360 has 100% true leaf.
# Tree 1362 has 100% true leaf.
# Tree 1364 has 100% true leaf.
# Tree 1365 has 100% true leaf.
# Tree 1373 has 100% true leaf.
# Tree 1375 has 100% true leaf.
# Tree 1376 has 100% true leaf.
# Tree 1385 has 100% true leaf.
# Tree 1387 has 100% true leaf.
# Tree 1398 has 100% true leaf.
# Tree 1400 has 100% true leaf.
# Tree 1403 has 100% true leaf.
# Tree 1406 has 100% true leaf.
# Tree 1410 has 100% true leaf.
# Tree 1412 has 100% true leaf.
# Tree 1419 has 100% true leaf.
# Tree 1420 has 100% true leaf.
# Tree 1424 has 100% true leaf.
# Tree 1425 has 100% true leaf.
# Tree 1433 has 100% true leaf.
# Tree 1437 has 100% true leaf.
# Tree 1442 has 100% true leaf.
# Tree 1448 has 100% true leaf.
# Tree 1458 has 100% true leaf.
# Tree 1461 has 100% true leaf.
# Tree 1462 has 100% true leaf.
# Tree 1465 has 100% true leaf.
# Tree 1465 has 100% true leaf.
# Tree 1466 has 100% true leaf.
# Tree 1467 has 100% true leaf.
# Tree 1476 has 100% true leaf.
# Tree 1483 has 100% true leaf.
# Tree 1484 has 100% true leaf.
# Tree 1496 has 100% true leaf.
# Tree 1503 has 100% true leaf.
# Tree 1507 has 100% true leaf.
# Tree 1511 has 100% true leaf.
# Tree 1516 has 100% true leaf.
# Tree 1519 has 100% true leaf.
# Tree 1521 has 100% true leaf.
# Tree 1523 has 100% true leaf.
# Tree 1524 has 100% true leaf.
# Tree 1545 has 100% true leaf.
# Tree 1555 has 100% true leaf.
# Tree 1555 has 100% true leaf.
# Tree 1561 has 100% true leaf.
# Tree 1562 has 100% true leaf.
# Tree 1563 has 100% true leaf.
# Tree 1564 has 100% true leaf.
# Tree 1566 has 100% true leaf.
# Tree 1579 has 100% true leaf.
# Tree 1579 has 100% true leaf.
# Tree 1583 has 100% true leaf.
# Tree 1584 has 100% true leaf.
# Tree 1587 has 100% true leaf.
# Tree 1603 has 100% true leaf.
# Tree 1607 has 100% true leaf.
# Tree 1607 has 100% true leaf.
# Tree 1611 has 100% true leaf.
# Tree 1614 has 100% true leaf.
# Tree 1617 has 100% true leaf.
# Tree 1621 has 100% true leaf.
# Tree 1623 has 100% true leaf.
# Tree 1631 has 100% true leaf.
# Tree 1640 has 100% true leaf.
# Tree 1641 has 100% true leaf.
# Tree 1643 has 100% true leaf.
# Tree 1645 has 100% true leaf.
# Tree 1649 has 100% true leaf.
# Tree 1652 has 100% true leaf.
# Tree 1656 has 100% true leaf.
# Tree 1657 has 100% true leaf.
# Tree 1660 has 100% true leaf.
# Tree 1661 has 100% true leaf.
# Tree 1669 has 100% true leaf.
# Tree 1675 has 100% true leaf.
# Tree 1675 has 100% true leaf.
# Tree 1676 has 100% true leaf.
# Tree 1677 has 100% true leaf.
# Tree 1679 has 100% true leaf.
# Tree 1681 has 100% true leaf.
# Tree 1682 has 100% true leaf.
# Tree 1682 has 100% true leaf.
# Tree 1684 has 100% true leaf.
# Tree 1685 has 100% true leaf.
# Tree 1687 has 100% true leaf.
# Tree 1689 has 100% true leaf.
# Tree 1695 has 100% true leaf.
# Tree 1695 has 100% true leaf.
# Tree 1702 has 100% true leaf.
# Tree 1709 has 100% true leaf.
# Tree 1714 has 100% true leaf.
# Tree 1716 has 100% true leaf.
# Tree 1718 has 100% true leaf.
# Tree 1719 has 100% true leaf.
# Tree 1720 has 100% true leaf.
# Tree 1726 has 100% true leaf.
# Tree 1727 has 100% true leaf.
# Tree 1731 has 100% true leaf.
# Tree 1732 has 100% true leaf.
# Tree 1733 has 100% true leaf.
# Tree 1734 has 100% true leaf.
# Tree 1737 has 100% true leaf.
# Tree 1738 has 100% true leaf.
# Tree 1739 has 100% true leaf.
# Tree 1740 has 100% true leaf.
# Tree 1741 has 100% true leaf.
# Tree 1745 has 100% true leaf.
# Tree 1749 has 100% true leaf.
# Tree 1752 has 100% true leaf.
# Tree 1759 has 100% true leaf.
# Tree 1775 has 100% true leaf.
# Tree 1776 has 100% true leaf.
# Tree 1779 has 100% true leaf.
# Tree 1780 has 100% true leaf.
# Tree 1784 has 100% true leaf.
# Tree 1785 has 100% true leaf.
# Tree 1785 has 100% true leaf.
# Tree 1788 has 100% true leaf.
# Tree 1790 has 100% true leaf.
# Tree 1793 has 100% true leaf.
# Tree 1800 has 100% true leaf.
# Tree 1801 has 100% true leaf.
# Tree 1802 has 100% true leaf.
# Tree 1804 has 100% true leaf.
# Tree 1811 has 100% true leaf.
# Tree 1813 has 100% true leaf.
# Tree 1814 has 100% true leaf.
# Tree 1816 has 100% true leaf.
# Tree 1816 has 100% true leaf.
# Tree 1819 has 100% true leaf.
# Tree 1820 has 100% true leaf.
# Tree 1825 has 100% true leaf.
# Tree 1829 has 100% true leaf.
# Tree 1830 has 100% true leaf.
# Tree 1833 has 100% true leaf.
# Tree 1858 has 100% true leaf.
# Tree 1860 has 100% true leaf.
# Tree 1862 has 100% true leaf.
# Tree 1863 has 100% true leaf.
# Tree 1869 has 100% true leaf.
# Tree 1870 has 100% true leaf.
# Tree 1871 has 100% true leaf.
# Tree 1874 has 100% true leaf.
# Tree 1891 has 100% true leaf.
# Tree 1893 has 100% true leaf.
# Tree 1894 has 100% true leaf.
# Tree 1895 has 100% true leaf.
# Tree 1896 has 100% true leaf.
# Tree 1897 has 100% true leaf.
# Tree 1899 has 100% true leaf.
# Tree 1899 has 100% true leaf.
# Tree 1904 has 100% true leaf.
# Tree 1905 has 100% true leaf.
# Tree 1908 has 100% true leaf.
# Tree 1909 has 100% true leaf.
# Tree 1909 has 100% true leaf.
# Tree 1914 has 100% true leaf.
# Tree 1918 has 100% true leaf.
# Tree 1921 has 100% true leaf.
# Tree 1922 has 100% true leaf.
# Tree 1935 has 100% true leaf.
# Tree 1939 has 100% true leaf.
# Tree 1940 has 100% true leaf.
# Tree 1941 has 100% true leaf.
# Tree 1943 has 100% true leaf.
# Tree 1944 has 100% true leaf.
# Tree 1947 has 100% true leaf.
# Tree 1947 has 100% true leaf.
# Tree 1950 has 100% true leaf.
# Tree 1951 has 100% true leaf.
# Tree 1957 has 100% true leaf.
# Tree 1961 has 100% true leaf.
# Tree 1962 has 100% true leaf.
# Tree 1967 has 100% true leaf.
# Tree 1970 has 100% true leaf.
# Tree 1976 has 100% true leaf.
# Tree 1978 has 100% true leaf.
# Tree 1981 has 100% true leaf.
# Tree 1983 has 100% true leaf.
# Tree 1986 has 100% true leaf.
# Tree 1987 has 100% true leaf.
# Tree 1988 has 100% true leaf.
# Tree 1991 has 100% true leaf.
# Tree 1993 has 100% true leaf.
# Tree 1995 has 100% true leaf.
# Tree 1997 has 100% true leaf.
# Tree 2005 has 100% true leaf.
# Tree 2008 has 100% true leaf.
# Tree 2020 has 100% true leaf.
# Tree 2024 has 100% true leaf.
# Tree 2031 has 100% true leaf.
# Tree 2034 has 100% true leaf.
# Tree 2039 has 100% true leaf.
# Tree 2041 has 100% true leaf.
# Tree 2043 has 100% true leaf.
# Tree 2044 has 100% true leaf.
# Tree 2051 has 100% true leaf.
# Tree 2052 has 100% true leaf.
# Tree 2054 has 100% true leaf.
# Tree 2055 has 100% true leaf.
# Tree 2056 has 100% true leaf.
# Tree 2058 has 100% true leaf.
# Tree 2059 has 100% true leaf.
# Tree 2061 has 100% true leaf.
# Tree 2066 has 100% true leaf.
# Tree 2067 has 100% true leaf.
# Tree 2068 has 100% true leaf.
# Tree 2075 has 100% true leaf.
# Tree 2076 has 100% true leaf.
# Tree 2078 has 100% true leaf.
# Tree 2087 has 100% true leaf.
# Tree 2092 has 100% true leaf.
# Tree 2101 has 100% true leaf.
# Tree 2103 has 100% true leaf.
# Tree 2104 has 100% true leaf.
# Tree 2109 has 100% true leaf.
# Tree 2115 has 100% true leaf.
# Tree 2116 has 100% true leaf.
# Tree 2123 has 100% true leaf.
# Tree 2125 has 100% true leaf.
# Tree 2137 has 100% true leaf.
# Tree 2142 has 100% true leaf.
# Tree 2144 has 100% true leaf.
# Tree 2152 has 100% true leaf.
# Tree 2153 has 100% true leaf.
# Tree 2158 has 100% true leaf.
# Tree 2162 has 100% true leaf.
# Tree 2163 has 100% true leaf.
# Tree 2166 has 100% true leaf.
# Tree 2166 has 100% true leaf.
# Tree 2167 has 100% true leaf.
# Tree 2170 has 100% true leaf.
# Tree 2173 has 100% true leaf.
# Tree 2174 has 100% true leaf.
# Tree 2179 has 100% true leaf.
# Tree 2180 has 100% true leaf.
# Tree 2182 has 100% true leaf.
# Tree 2184 has 100% true leaf.
# Tree 2187 has 100% true leaf.
# Tree 2188 has 100% true leaf.
# Tree 2190 has 100% true leaf.
# Tree 2193 has 100% true leaf.
# Tree 2205 has 100% true leaf.
# Tree 2208 has 100% true leaf.
# Tree 2209 has 100% true leaf.
# Tree 2212 has 100% true leaf.
# Tree 2221 has 100% true leaf.
# Tree 2221 has 100% true leaf.
# Tree 2225 has 100% true leaf.
# Tree 2234 has 100% true leaf.
# Tree 2236 has 100% true leaf.
# Tree 2243 has 100% true leaf.
# Tree 2246 has 100% true leaf.
# Tree 2247 has 100% true leaf.
# Tree 2249 has 100% true leaf.
# Tree 2263 has 100% true leaf.
# Tree 2274 has 100% true leaf.
# Tree 2275 has 100% true leaf.
# Tree 2278 has 100% true leaf.
# Tree 2279 has 100% true leaf.
# Tree 2281 has 100% true leaf.
# Tree 2281 has 100% true leaf.
# Tree 2282 has 100% true leaf.
# Tree 2282 has 100% true leaf.
# Tree 2286 has 100% true leaf.
# Tree 2289 has 100% true leaf.
# Tree 2296 has 100% true leaf.
# Tree 2298 has 100% true leaf.
# Tree 2304 has 100% true leaf.
# Tree 2309 has 100% true leaf.
# Tree 2309 has 100% true leaf.
# Tree 2310 has 100% true leaf.
# Tree 2311 has 100% true leaf.
# Tree 2312 has 100% true leaf.
# Tree 2315 has 100% true leaf.
# Tree 2317 has 100% true leaf.
# Tree 2320 has 100% true leaf.
# Tree 2323 has 100% true leaf.
# Tree 2326 has 100% true leaf.
# Tree 2337 has 100% true leaf.
# Tree 2349 has 100% true leaf.
# Tree 2350 has 100% true leaf.
# Tree 2355 has 100% true leaf.
# Tree 2359 has 100% true leaf.
# Tree 2359 has 100% true leaf.
# Tree 2361 has 100% true leaf.
# Tree 2363 has 100% true leaf.
# Tree 2366 has 100% true leaf.
# Tree 2366 has 100% true leaf.
# Tree 2373 has 100% true leaf.
# Tree 2373 has 100% true leaf.
# Tree 2381 has 100% true leaf.
# Tree 2383 has 100% true leaf.
# Tree 2387 has 100% true leaf.
# Tree 2388 has 100% true leaf.
# Tree 2394 has 100% true leaf.
# Tree 2408 has 100% true leaf.
# Tree 2419 has 100% true leaf.
# Tree 2420 has 100% true leaf.
# Tree 2427 has 100% true leaf.
# Tree 2433 has 100% true leaf.
# Tree 2434 has 100% true leaf.
# Tree 2447 has 100% true leaf.
# Tree 2447 has 100% true leaf.
# Tree 2448 has 100% true leaf.
# Tree 2452 has 100% true leaf.
# Tree 2453 has 100% true leaf.
# Tree 2472 has 100% true leaf.
# Tree 2476 has 100% true leaf.
# Tree 2483 has 100% true leaf.
# Tree 2485 has 100% true leaf.
# Tree 2490 has 100% true leaf.
# Tree 2492 has 100% true leaf.
# Tree 2493 has 100% true leaf.
# Tree 2494 has 100% true leaf.
# Tree 2497 has 100% true leaf.
# Tree 2499 has 100% true leaf.
# Tree 2505 has 100% true leaf.
# Tree 2507 has 100% true leaf.
# Tree 2507 has 100% true leaf.
# Tree 2508 has 100% true leaf.
# Tree 2509 has 100% true leaf.
# Tree 2511 has 100% true leaf.
# Tree 2513 has 100% true leaf.
# Tree 2514 has 100% true leaf.
# Tree 2515 has 100% true leaf.
# Tree 2518 has 100% true leaf.
# Tree 2522 has 100% true leaf.
# Tree 2523 has 100% true leaf.
# Tree 2524 has 100% true leaf.
# Tree 2525 has 100% true leaf.
# Tree 2529 has 100% true leaf.
# Tree 2532 has 100% true leaf.
# Tree 2535 has 100% true leaf.
# Tree 2541 has 100% true leaf.
# Tree 2542 has 100% true leaf.
# Tree 2545 has 100% true leaf.
# Tree 2546 has 100% true leaf.
# Tree 2550 has 100% true leaf.
# Tree 2554 has 100% true leaf.
# Tree 2561 has 100% true leaf.
# Tree 2562 has 100% true leaf.
# Tree 2564 has 100% true leaf.
# Tree 2565 has 100% true leaf.
# Tree 2565 has 100% true leaf.
# Tree 2567 has 100% true leaf.
# Tree 2568 has 100% true leaf.
# Tree 2576 has 100% true leaf.
# Tree 2579 has 100% true leaf.
# Tree 2579 has 100% true leaf.
# Tree 2583 has 100% true leaf.
# Tree 2588 has 100% true leaf.
# Tree 2591 has 100% true leaf.
# Tree 2595 has 100% true leaf.
# Tree 2597 has 100% true leaf.
# Tree 2598 has 100% true leaf.
# Tree 2602 has 100% true leaf.
# Tree 2611 has 100% true leaf.
# Tree 2612 has 100% true leaf.
# Tree 2613 has 100% true leaf.
# Tree 2617 has 100% true leaf.
# Tree 2617 has 100% true leaf.
# Tree 2618 has 100% true leaf.
# Tree 2622 has 100% true leaf.
# Tree 2625 has 100% true leaf.
# Tree 2627 has 100% true leaf.
# Tree 2629 has 100% true leaf.
# Tree 2630 has 100% true leaf.
# Tree 2631 has 100% true leaf.
# Tree 2637 has 100% true leaf.
# Tree 2639 has 100% true leaf.
# Tree 2642 has 100% true leaf.
# Tree 2644 has 100% true leaf.
# Tree 2648 has 100% true leaf.
# Tree 2649 has 100% true leaf.
# Tree 2652 has 100% true leaf.
# Tree 2653 has 100% true leaf.
# Tree 2655 has 100% true leaf.
# Tree 2657 has 100% true leaf.
# Tree 2661 has 100% true leaf.
# Tree 2663 has 100% true leaf.
# Tree 2667 has 100% true leaf.
# Tree 2667 has 100% true leaf.
# Tree 2683 has 100% true leaf.
# Tree 2684 has 100% true leaf.
# Tree 2687 has 100% true leaf.
# Tree 2692 has 100% true leaf.
# Tree 2700 has 100% true leaf.
# Tree 2701 has 100% true leaf.
# Tree 2704 has 100% true leaf.
# Tree 2707 has 100% true leaf.
# Tree 2708 has 100% true leaf.
# Tree 2710 has 100% true leaf.
# Tree 2720 has 100% true leaf.
# Tree 2722 has 100% true leaf.
# Tree 2729 has 100% true leaf.
# Tree 2739 has 100% true leaf.
# Tree 2739 has 100% true leaf.
# Tree 2747 has 100% true leaf.
# Tree 2749 has 100% true leaf.
# Tree 2751 has 100% true leaf.
# Tree 2755 has 100% true leaf.
# Tree 2761 has 100% true leaf.
# Tree 2775 has 100% true leaf.
# Tree 2776 has 100% true leaf.
# Tree 2778 has 100% true leaf.
# Tree 2782 has 100% true leaf.
# Tree 2785 has 100% true leaf.
# Tree 2787 has 100% true leaf.
# Tree 2789 has 100% true leaf.
# Tree 2795 has 100% true leaf.
# Tree 2796 has 100% true leaf.
# Tree 2798 has 100% true leaf.
# Tree 2803 has 100% true leaf.
# Tree 2807 has 100% true leaf.
# Tree 2808 has 100% true leaf.
# Tree 2814 has 100% true leaf.
# Tree 2815 has 100% true leaf.
# Tree 2817 has 100% true leaf.
# Tree 2820 has 100% true leaf.
# Tree 2826 has 100% true leaf.
# Tree 2827 has 100% true leaf.
# Tree 2829 has 100% true leaf.
# Tree 2829 has 100% true leaf.
# Tree 2830 has 100% true leaf.
# Tree 2835 has 100% true leaf.
# Tree 2836 has 100% true leaf.
# Tree 2839 has 100% true leaf.
# Tree 2843 has 100% true leaf.
# Tree 2846 has 100% true leaf.
# Tree 2848 has 100% true leaf.
# Tree 2849 has 100% true leaf.
# Tree 2854 has 100% true leaf.
# Tree 2856 has 100% true leaf.
# Tree 2856 has 100% true leaf.
# Tree 2857 has 100% true leaf.
# Tree 2860 has 100% true leaf.
# Tree 2865 has 100% true leaf.
# Tree 2867 has 100% true leaf.
# Tree 2869 has 100% true leaf.
# Tree 2869 has 100% true leaf.
# Tree 2870 has 100% true leaf.
# Tree 2872 has 100% true leaf.
# Tree 2872 has 100% true leaf.
# Tree 2874 has 100% true leaf.
# Tree 2887 has 100% true leaf.
# Tree 2888 has 100% true leaf.
# Tree 2889 has 100% true leaf.
# Tree 2899 has 100% true leaf.
# Tree 2903 has 100% true leaf.
# Tree 2907 has 100% true leaf.
# Tree 2909 has 100% true leaf.
# Tree 2911 has 100% true leaf.
# Tree 2912 has 100% true leaf.
# Tree 2913 has 100% true leaf.
# Tree 2915 has 100% true leaf.
# Tree 2923 has 100% true leaf.
# Tree 2924 has 100% true leaf.
# Tree 2926 has 100% true leaf.
# Tree 2926 has 100% true leaf.
# Tree 2927 has 100% true leaf.
# Tree 2930 has 100% true leaf.
# Tree 2930 has 100% true leaf.
# Tree 2935 has 100% true leaf.
# Tree 2936 has 100% true leaf.
# Tree 2938 has 100% true leaf.
# Tree 2948 has 100% true leaf.
# Tree 2949 has 100% true leaf.
# Tree 2950 has 100% true leaf.
# Tree 2951 has 100% true leaf.
# Tree 2956 has 100% true leaf.
# Tree 2958 has 100% true leaf.
# Tree 2959 has 100% true leaf.
# Tree 2965 has 100% true leaf.
# Tree 2965 has 100% true leaf.
# Tree 2968 has 100% true leaf.
# Tree 2970 has 100% true leaf.
# Tree 2976 has 100% true leaf.
# Tree 2984 has 100% true leaf.
# Tree 2985 has 100% true leaf.
# Tree 2987 has 100% true leaf.
# Tree 2990 has 100% true leaf.
# Tree 2997 has 100% true leaf.
# Tree 2999 has 100% true leaf.
# Tree 3002 has 100% true leaf.
# Tree 3003 has 100% true leaf.
# Tree 3004 has 100% true leaf.
# Tree 3008 has 100% true leaf.
# Tree 3010 has 100% true leaf.
# Tree 3011 has 100% true leaf.
# Tree 3019 has 100% true leaf.
# Tree 3020 has 100% true leaf.
# Tree 3025 has 100% true leaf.
# Tree 3039 has 100% true leaf.
# Tree 3040 has 100% true leaf.
# Tree 3041 has 100% true leaf.
# Tree 3043 has 100% true leaf.
# Tree 3045 has 100% true leaf.
# Tree 3048 has 100% true leaf.
# Tree 3050 has 100% true leaf.
# Tree 3053 has 100% true leaf.
# Tree 3054 has 100% true leaf.
# Tree 3056 has 100% true leaf.
# Tree 3061 has 100% true leaf.
# Tree 3064 has 100% true leaf.
# Tree 3068 has 100% true leaf.
# Tree 3070 has 100% true leaf.
# Tree 3070 has 100% true leaf.
# Tree 3072 has 100% true leaf.
# Tree 3073 has 100% true leaf.
# Tree 3074 has 100% true leaf.
# Tree 3074 has 100% true leaf.
# Tree 3075 has 100% true leaf.
# Tree 3079 has 100% true leaf.
# Tree 3080 has 100% true leaf.
# Tree 3084 has 100% true leaf.
# Tree 3092 has 100% true leaf.
# Tree 3095 has 100% true leaf.
# Tree 3098 has 100% true leaf.
# Tree 3101 has 100% true leaf.
# Tree 3109 has 100% true leaf.
# Tree 3110 has 100% true leaf.
# Tree 3110 has 100% true leaf.
# Tree 3115 has 100% true leaf.
# Tree 3116 has 100% true leaf.
# Tree 3119 has 100% true leaf.
# Tree 3122 has 100% true leaf.
# Tree 3124 has 100% true leaf.
# Tree 3131 has 100% true leaf.
# Tree 3134 has 100% true leaf.
# Tree 3138 has 100% true leaf.
# Tree 3140 has 100% true leaf.
# Tree 3143 has 100% true leaf.
# Tree 3149 has 100% true leaf.
# Tree 3156 has 100% true leaf.
# Tree 3156 has 100% true leaf.
# Tree 3158 has 100% true leaf.
# Tree 3160 has 100% true leaf.
# Tree 3164 has 100% true leaf.
# Tree 3164 has 100% true leaf.
# Tree 3165 has 100% true leaf.
# Tree 3166 has 100% true leaf.
# Tree 3168 has 100% true leaf.
# Tree 3171 has 100% true leaf.
# Tree 3176 has 100% true leaf.
# Tree 3183 has 100% true leaf.
# Tree 3184 has 100% true leaf.
# Tree 3190 has 100% true leaf.
# Tree 3190 has 100% true leaf.
# Tree 3191 has 100% true leaf.
# Tree 3192 has 100% true leaf.
# Tree 3192 has 100% true leaf.
# Tree 3193 has 100% true leaf.
# Tree 3195 has 100% true leaf.
# Tree 3208 has 100% true leaf.
# Tree 3215 has 100% true leaf.
# Tree 3216 has 100% true leaf.
# Tree 3218 has 100% true leaf.
# Tree 3219 has 100% true leaf.
# Tree 3222 has 100% true leaf.
# Tree 3227 has 100% true leaf.
# Tree 3229 has 100% true leaf.
# Tree 3240 has 100% true leaf.
# Tree 3244 has 100% true leaf.
# Tree 3244 has 100% true leaf.
# Tree 3252 has 100% true leaf.
# Tree 3253 has 100% true leaf.
# Tree 3255 has 100% true leaf.
# Tree 3256 has 100% true leaf.
# Tree 3261 has 100% true leaf.
# Tree 3262 has 100% true leaf.
# Tree 3262 has 100% true leaf.
# Tree 3264 has 100% true leaf.
# Tree 3264 has 100% true leaf.
# Tree 3274 has 100% true leaf.
# Tree 3280 has 100% true leaf.
# Tree 3282 has 100% true leaf.
# Tree 3282 has 100% true leaf.
# Tree 3287 has 100% true leaf.
# Tree 3288 has 100% true leaf.
# Tree 3291 has 100% true leaf.
# Tree 3292 has 100% true leaf.
# Tree 3293 has 100% true leaf.
# Tree 3294 has 100% true leaf.
# Tree 3295 has 100% true leaf.
# Tree 3298 has 100% true leaf.
# Tree 3310 has 100% true leaf.
# Tree 3311 has 100% true leaf.
# Tree 3312 has 100% true leaf.
# Tree 3313 has 100% true leaf.
# Tree 3314 has 100% true leaf.
# Tree 3316 has 100% true leaf.
# Tree 3325 has 100% true leaf.
# Tree 3329 has 100% true leaf.
# Tree 3338 has 100% true leaf.
# Tree 3346 has 100% true leaf.
# Tree 3349 has 100% true leaf.
# Tree 3350 has 100% true leaf.
# Tree 3358 has 100% true leaf.
# Tree 3377 has 100% true leaf.
# Tree 3380 has 100% true leaf.
# Tree 3388 has 100% true leaf.
# Tree 3389 has 100% true leaf.
# Tree 3392 has 100% true leaf.
# Tree 3396 has 100% true leaf.
# Tree 3398 has 100% true leaf.
# Tree 3399 has 100% true leaf.
# Tree 3400 has 100% true leaf.
# Tree 3401 has 100% true leaf.
# Tree 3402 has 100% true leaf.
# Tree 3403 has 100% true leaf.
# Tree 3404 has 100% true leaf.
# Tree 3406 has 100% true leaf.
# Tree 3412 has 100% true leaf.
# Tree 3421 has 100% true leaf.
# Tree 3444 has 100% true leaf.
# Tree 3446 has 100% true leaf.
# Tree 3453 has 100% true leaf.
# Tree 3456 has 100% true leaf.
# Tree 3459 has 100% true leaf.
# Tree 3460 has 100% true leaf.
# Tree 3469 has 100% true leaf.
# Tree 3470 has 100% true leaf.
# Tree 3471 has 100% true leaf.
# Tree 3473 has 100% true leaf.
# Tree 3473 has 100% true leaf.
# Tree 3476 has 100% true leaf.
# Tree 3478 has 100% true leaf.
# Tree 3480 has 100% true leaf.
# Tree 3488 has 100% true leaf.
# Tree 3488 has 100% true leaf.
# Tree 3491 has 100% true leaf.
# Tree 3499 has 100% true leaf.
# Tree 3500 has 100% true leaf.
# Tree 3508 has 100% true leaf.
# Tree 3509 has 100% true leaf.
# Tree 3510 has 100% true leaf.
# Tree 3515 has 100% true leaf.
# Tree 3516 has 100% true leaf.
# Tree 3519 has 100% true leaf.
# Tree 3522 has 100% true leaf.
# Tree 3529 has 100% true leaf.
# Tree 3529 has 100% true leaf.
# Tree 3534 has 100% true leaf.
# Tree 3547 has 100% true leaf.
# Tree 3550 has 100% true leaf.
# Tree 3550 has 100% true leaf.
# Tree 3551 has 100% true leaf.
# Tree 3558 has 100% true leaf.
# Tree 3559 has 100% true leaf.
# Tree 3565 has 100% true leaf.
# Tree 3567 has 100% true leaf.
# Tree 3567 has 100% true leaf.
# Tree 3569 has 100% true leaf.
# Tree 3570 has 100% true leaf.
# Tree 3571 has 100% true leaf.
# Tree 3573 has 100% true leaf.
# Tree 3574 has 100% true leaf.
# Tree 3577 has 100% true leaf.
# Tree 3581 has 100% true leaf.
# Tree 3585 has 100% true leaf.
# Tree 3592 has 100% true leaf.
# Tree 3595 has 100% true leaf.
# Tree 3598 has 100% true leaf.
# Tree 3603 has 100% true leaf.
# Tree 3604 has 100% true leaf.
# Tree 3612 has 100% true leaf.
# Tree 3616 has 100% true leaf.
# Tree 3624 has 100% true leaf.
# Tree 3631 has 100% true leaf.
# Tree 3636 has 100% true leaf.
# Tree 3639 has 100% true leaf.
# Tree 3640 has 100% true leaf.
# Tree 3641 has 100% true leaf.
# Tree 3642 has 100% true leaf.
# Tree 3644 has 100% true leaf.
# Tree 3645 has 100% true leaf.
# Tree 3646 has 100% true leaf.
# Tree 3647 has 100% true leaf.
# Tree 3649 has 100% true leaf.
# Tree 3651 has 100% true leaf.
# Tree 3655 has 100% true leaf.
# Tree 3656 has 100% true leaf.
# Tree 3657 has 100% true leaf.
# Tree 3660 has 100% true leaf.
# Tree 3661 has 100% true leaf.
# Tree 3666 has 100% true leaf.
# Tree 3666 has 100% true leaf.
# Tree 3670 has 100% true leaf.
# Tree 3673 has 100% true leaf.
# Tree 3677 has 100% true leaf.
# Tree 3678 has 100% true leaf.
# Tree 3687 has 100% true leaf.
# Tree 3688 has 100% true leaf.
# Tree 3693 has 100% true leaf.
# Tree 3694 has 100% true leaf.
# Tree 3709 has 100% true leaf.
# Tree 3710 has 100% true leaf.
# Tree 3712 has 100% true leaf.
# Tree 3719 has 100% true leaf.
# Tree 3719 has 100% true leaf.
# Tree 3721 has 100% true leaf.
# Tree 3723 has 100% true leaf.
# Tree 3724 has 100% true leaf.
# Tree 3728 has 100% true leaf.
# Tree 3731 has 100% true leaf.
# Tree 3740 has 100% true leaf.
# Tree 3748 has 100% true leaf.
# Tree 3750 has 100% true leaf.
# Tree 3752 has 100% true leaf.
# Tree 3758 has 100% true leaf.
# Tree 3759 has 100% true leaf.
# Tree 3762 has 100% true leaf.
# Tree 3763 has 100% true leaf.
# Tree 3767 has 100% true leaf.
# Tree 3776 has 100% true leaf.
# Tree 3784 has 100% true leaf.
# Tree 3786 has 100% true leaf.
# Tree 3793 has 100% true leaf.
# Tree 3794 has 100% true leaf.
# Tree 3795 has 100% true leaf.
# Tree 3798 has 100% true leaf.
# Tree 3799 has 100% true leaf.
# Tree 3802 has 100% true leaf.
# Tree 3807 has 100% true leaf.
# Tree 3808 has 100% true leaf.
# Tree 3808 has 100% true leaf.
# Tree 3808 has 100% true leaf.
# Tree 3812 has 100% true leaf.
# Tree 3813 has 100% true leaf.
# Tree 3815 has 100% true leaf.
# Tree 3831 has 100% true leaf.
# Tree 3832 has 100% true leaf.
# Tree 3834 has 100% true leaf.
# Tree 3839 has 100% true leaf.
# Tree 3842 has 100% true leaf.
# Tree 3846 has 100% true leaf.
# Tree 3853 has 100% true leaf.
# Tree 3854 has 100% true leaf.
# Tree 3862 has 100% true leaf.
# Tree 3866 has 100% true leaf.
# Tree 3885 has 100% true leaf.
# Tree 3889 has 100% true leaf.
# Tree 3890 has 100% true leaf.
# Tree 3892 has 100% true leaf.
# Tree 3897 has 100% true leaf.
# Tree 3899 has 100% true leaf.
# Tree 3912 has 100% true leaf.
# Tree 3919 has 100% true leaf.
# Tree 3924 has 100% true leaf.
# Tree 3928 has 100% true leaf.
# Tree 3929 has 100% true leaf.
# Tree 3934 has 100% true leaf.
# Tree 3940 has 100% true leaf.
# Tree 3942 has 100% true leaf.
# Tree 3948 has 100% true leaf.
# Tree 3949 has 100% true leaf.
# Tree 3956 has 100% true leaf.
# Tree 3957 has 100% true leaf.
# Tree 3959 has 100% true leaf.
# Tree 3966 has 100% true leaf.
# Tree 3968 has 100% true leaf.
# Tree 3973 has 100% true leaf.
# Tree 3974 has 100% true leaf.
# Tree 3977 has 100% true leaf.
# Tree 3979 has 100% true leaf.
# Tree 3980 has 100% true leaf.
# Tree 3982 has 100% true leaf.
# Tree 3985 has 100% true leaf.
# Tree 3987 has 100% true leaf.
# Tree 3988 has 100% true leaf.
# Tree 3989 has 100% true leaf.
# Tree 3990 has 100% true leaf.
# Tree 3992 has 100% true leaf.
# Tree 3994 has 100% true leaf.
# Tree 3996 has 100% true leaf.
# Tree 4006 has 100% true leaf.
# Tree 4010 has 100% true leaf.
# Tree 4011 has 100% true leaf.
# Tree 4016 has 100% true leaf.
# Tree 4019 has 100% true leaf.
# Tree 4022 has 100% true leaf.
# Tree 4022 has 100% true leaf.
# Tree 4025 has 100% true leaf.
# Tree 4027 has 100% true leaf.
# Tree 4036 has 100% true leaf.
# Tree 4037 has 100% true leaf.
# Tree 4038 has 100% true leaf.
# Tree 4041 has 100% true leaf.
# Tree 4043 has 100% true leaf.
# Tree 4045 has 100% true leaf.
# Tree 4046 has 100% true leaf.
# Tree 4048 has 100% true leaf.
# Tree 4049 has 100% true leaf.
# Tree 4050 has 100% true leaf.
# Tree 4058 has 100% true leaf.
# Tree 4059 has 100% true leaf.
# Tree 4061 has 100% true leaf.
# Tree 4073 has 100% true leaf.
# Tree 4074 has 100% true leaf.
# Tree 4079 has 100% true leaf.
# Tree 4081 has 100% true leaf.
# Tree 4081 has 100% true leaf.
# Tree 4082 has 100% true leaf.
# Tree 4083 has 100% true leaf.
# Tree 4086 has 100% true leaf.
# Tree 4092 has 100% true leaf.
# Tree 4097 has 100% true leaf.
# Tree 4101 has 100% true leaf.
# Tree 4108 has 100% true leaf.
# Tree 4110 has 100% true leaf.
# Tree 4112 has 100% true leaf.
# Tree 4114 has 100% true leaf.
# Tree 4123 has 100% true leaf.
# Tree 4124 has 100% true leaf.
# Tree 4132 has 100% true leaf.
# Tree 4134 has 100% true leaf.
# Tree 4136 has 100% true leaf.
# Tree 4137 has 100% true leaf.
# Tree 4139 has 100% true leaf.
# Tree 4141 has 100% true leaf.
# Tree 4143 has 100% true leaf.
# Tree 4148 has 100% true leaf.
# Tree 4158 has 100% true leaf.
# Tree 4159 has 100% true leaf.
# Tree 4163 has 100% true leaf.
# Tree 4167 has 100% true leaf.
# Tree 4171 has 100% true leaf.
# Tree 4172 has 100% true leaf.
# Tree 4174 has 100% true leaf.
# Tree 4191 has 100% true leaf.
# Tree 4196 has 100% true leaf.
# Tree 4199 has 100% true leaf.
# Tree 4200 has 100% true leaf.
# Tree 4201 has 100% true leaf.
# Tree 4208 has 100% true leaf.
# Tree 4210 has 100% true leaf.
# Tree 4211 has 100% true leaf.
# Tree 4224 has 100% true leaf.
# Tree 4224 has 100% true leaf.
# Tree 4230 has 100% true leaf.
# Tree 4236 has 100% true leaf.
# Tree 4237 has 100% true leaf.
# Tree 4243 has 100% true leaf.
# Tree 4245 has 100% true leaf.
# Tree 4251 has 100% true leaf.
# Tree 4256 has 100% true leaf.
# Tree 4265 has 100% true leaf.
# Tree 4267 has 100% true leaf.
# Tree 4267 has 100% true leaf.
# Tree 4272 has 100% true leaf.
# Tree 4275 has 100% true leaf.
# Tree 4276 has 100% true leaf.
# Tree 4281 has 100% true leaf.
# Tree 4286 has 100% true leaf.
# Tree 4287 has 100% true leaf.
# Tree 4288 has 100% true leaf.
# Tree 4291 has 100% true leaf.
# Tree 4294 has 100% true leaf.
# Tree 4305 has 100% true leaf.
# Tree 4306 has 100% true leaf.
# Tree 4306 has 100% true leaf.
# Tree 4309 has 100% true leaf.
# Tree 4310 has 100% true leaf.
# Tree 4312 has 100% true leaf.
# Tree 4315 has 100% true leaf.
# Tree 4320 has 100% true leaf.
# Tree 4321 has 100% true leaf.
# Tree 4322 has 100% true leaf.
# Tree 4322 has 100% true leaf.
# Tree 4326 has 100% true leaf.
# Tree 4326 has 100% true leaf.
# Tree 4327 has 100% true leaf.
# Tree 4333 has 100% true leaf.
# Tree 4350 has 100% true leaf.
# Tree 4352 has 100% true leaf.
# Tree 4353 has 100% true leaf.
# Tree 4357 has 100% true leaf.
# Tree 4359 has 100% true leaf.
# Tree 4360 has 100% true leaf.
# Tree 4365 has 100% true leaf.
# Tree 4366 has 100% true leaf.
# Tree 4371 has 100% true leaf.
# Tree 4373 has 100% true leaf.
# Tree 4390 has 100% true leaf.
# Tree 4391 has 100% true leaf.
# Tree 4404 has 100% true leaf.
# Tree 4407 has 100% true leaf.
# Tree 4417 has 100% true leaf.
# Tree 4419 has 100% true leaf.
# Tree 4420 has 100% true leaf.
# Tree 4422 has 100% true leaf.
# Tree 4427 has 100% true leaf.
# Tree 4429 has 100% true leaf.
# Tree 4429 has 100% true leaf.
# Tree 4431 has 100% true leaf.
# Tree 4433 has 100% true leaf.
# Tree 4434 has 100% true leaf.
# Tree 4435 has 100% true leaf.
# Tree 4436 has 100% true leaf.
# Tree 4442 has 100% true leaf.
# Tree 4447 has 100% true leaf.
# Tree 4447 has 100% true leaf.
# Tree 4448 has 100% true leaf.
# Tree 4454 has 100% true leaf.
# Tree 4457 has 100% true leaf.
# Tree 4458 has 100% true leaf.
# Tree 4464 has 100% true leaf.
# Tree 4465 has 100% true leaf.
# Tree 4474 has 100% true leaf.
# Tree 4483 has 100% true leaf.
# Tree 4484 has 100% true leaf.
# Tree 4490 has 100% true leaf.
# Tree 4490 has 100% true leaf.
# Tree 4497 has 100% true leaf.
# Tree 4500 has 100% true leaf.
# Tree 4500 has 100% true leaf.
# Tree 4502 has 100% true leaf.
# Tree 4508 has 100% true leaf.
# Tree 4510 has 100% true leaf.
# Tree 4513 has 100% true leaf.
# Tree 4514 has 100% true leaf.
# Tree 4520 has 100% true leaf.
# Tree 4524 has 100% true leaf.
# Tree 4527 has 100% true leaf.
# Tree 4545 has 100% true leaf.
# Tree 4547 has 100% true leaf.
# Tree 4549 has 100% true leaf.
# Tree 4551 has 100% true leaf.
# Tree 4556 has 100% true leaf.
# Tree 4560 has 100% true leaf.
# Tree 4563 has 100% true leaf.
# Tree 4565 has 100% true leaf.
# Tree 4570 has 100% true leaf.
# Tree 4575 has 100% true leaf.
# Tree 4582 has 100% true leaf.
# Tree 4583 has 100% true leaf.
# Tree 4588 has 100% true leaf.
# Tree 4589 has 100% true leaf.
# Tree 4594 has 100% true leaf.
# Tree 4596 has 100% true leaf.
# Tree 4604 has 100% true leaf.
# Tree 4611 has 100% true leaf.
# Tree 4618 has 100% true leaf.
# Tree 4621 has 100% true leaf.
# Tree 4624 has 100% true leaf.
# Tree 4631 has 100% true leaf.
# Tree 4640 has 100% true leaf.
# Tree 4651 has 100% true leaf.
# Tree 4652 has 100% true leaf.
# Tree 4656 has 100% true leaf.
# Tree 4657 has 100% true leaf.
# Tree 4659 has 100% true leaf.
# Tree 4664 has 100% true leaf.
# Tree 4666 has 100% true leaf.
# Tree 4668 has 100% true leaf.
# Tree 4669 has 100% true leaf.
# Tree 4684 has 100% true leaf.
# Tree 4686 has 100% true leaf.
# Tree 4689 has 100% true leaf.
# Tree 4692 has 100% true leaf.
# Tree 4702 has 100% true leaf.
# Tree 4706 has 100% true leaf.
# Tree 4710 has 100% true leaf.
# Tree 4712 has 100% true leaf.
# Tree 4714 has 100% true leaf.
# Tree 4716 has 100% true leaf.
# Tree 4719 has 100% true leaf.
# Tree 4725 has 100% true leaf.
# Tree 4740 has 100% true leaf.
# Tree 4748 has 100% true leaf.
# Tree 4752 has 100% true leaf.
# Tree 4754 has 100% true leaf.
# Tree 4754 has 100% true leaf.
# Tree 4756 has 100% true leaf.
# Tree 4760 has 100% true leaf.
# Tree 4760 has 100% true leaf.
# Tree 4761 has 100% true leaf.
# Tree 4769 has 100% true leaf.
# Tree 4770 has 100% true leaf.
# Tree 4783 has 100% true leaf.
# Tree 4791 has 100% true leaf.
# Tree 4796 has 100% true leaf.
# Tree 4797 has 100% true leaf.
# Tree 4799 has 100% true leaf.
# Tree 4803 has 100% true leaf.
# Tree 4808 has 100% true leaf.
# Tree 4812 has 100% true leaf.
# Tree 4814 has 100% true leaf.
# Tree 4823 has 100% true leaf.
# Tree 4830 has 100% true leaf.
# Tree 4838 has 100% true leaf.
# Tree 4845 has 100% true leaf.
# Tree 4848 has 100% true leaf.
# Tree 4853 has 100% true leaf.
# Tree 4858 has 100% true leaf.
# Tree 4862 has 100% true leaf.
# Tree 4870 has 100% true leaf.
# Tree 4871 has 100% true leaf.
# Tree 4871 has 100% true leaf.
# Tree 4871 has 100% true leaf.
# Tree 4875 has 100% true leaf.
# Tree 4886 has 100% true leaf.
# Tree 4886 has 100% true leaf.
# Tree 4888 has 100% true leaf.
# Tree 4889 has 100% true leaf.
# Tree 4890 has 100% true leaf.
# Tree 4896 has 100% true leaf.
# Tree 4904 has 100% true leaf.
# Tree 4911 has 100% true leaf.
# Tree 4912 has 100% true leaf.
# Tree 4925 has 100% true leaf.
# Tree 4927 has 100% true leaf.
# Tree 4928 has 100% true leaf.
# Tree 4942 has 100% true leaf.
# Tree 4953 has 100% true leaf.
# Tree 4954 has 100% true leaf.
# Tree 4959 has 100% true leaf.
# Tree 4972 has 100% true leaf.
# Tree 4977 has 100% true leaf.
# Tree 4992 has 100% true leaf.
# Tree 4995 has 100% true leaf.
# Tree 4999 has 100% true leaf.

# %%
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree
import numpy as np

# 选择森林中的一棵树进行绘制
tree_num = 0         # 选择第n棵树
plt.rcParams['font.sans-serif'] = ['Microsoft YaHei']  # 更好的中文字体，可以显示“-”号
plt.figure(figsize=(60,30))
print(clf.classes_)
plot_tree(clf.estimators_[tree_num], 
          feature_names=cols_x_names,
          class_names=COLS_Y_CLASSNAME, 
          filled=True, 
          rounded=True)
plt.show()
# Out:
# [False  True]

# %%
#返回指定要求的满足要求的期号
mask = (df['号码1'] < 7.5) & (df['号码1'] > 6.5) & (df['是组三'] > 0.5) 
# mask = (df['本期是否有6'] <=0.5 ) & (df['跨度为偶数'] >0.5) & (df['本期是否有4'] >0.5) 
# mask = (df['本期是否有6'] <=0.5 ) & (df['跨度为偶数'] >0.5) & (df['本期是否有4'] <=0.5) & (df['和值'] >14)
# mask = (df['和值为偶数'] > 0.5 ) & (df['跨度为偶数'] >0.5) & (df['跨度'] >5)
# mask = (df['跨度'] <= 0.5 )
print(df.loc[mask]['期号'])
# Out:
# 9      2024261
# 47     2024223
# 146    2024124
# 183    2024087
# 190    2024080
# 271    2023350
# 302    2023319
# 375    2023246
# 391    2023230
# 442    2023179
# 479    2023142
# 481    2023140
# Name: 期号, dtype: int64
